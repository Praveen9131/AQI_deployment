# %%
import mne

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import signal
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.metrics import confusion_matrix, classification_report
import random

# %%
data =pd.read_csv(r"C:\Users\jogip\Desktop\NIT\Data\labels.csv")

# %%
data.head(10)
# Out:
#   experiment_code  arousal  valence   emotion
# 0      SUB01TST04        8        3      fear
# 1      SUB01TST03        3        1       sad
# 2      SUB01TST02        5        5   neutral
# 3      SUB01VID25        8        7  surprise
# 4      SUB01VID24        4        4       sad
# 5      SUB01VID23        3        3       sad
# 6      SUB01VID21        7        1     angry
# 7      SUB01VID20        8        1   disgust
# 8      SUB01VID19        2        5   neutral
# 9      SUB01VID18        8        2   disgust

# %%
from glob import glob
import os
import mne
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
root_path =r"C:\Users\jogip\Desktop\NIT\Data"

# %%
label_filepath= root_path+'\labels.csv'
label_df = pd.read_csv(label_filepath)

# %%
def get_label( file_path):

  # Extract the filename from the absolute path
  filename = os.path.basename(file_path)

# Split the filename into parts using "_" as the delimiter
  filename_parts = filename.split("_")


# Specify the experiment code you are interested in
  target_experiment_code = filename_parts[0]
  # print('*****',target_experiment_code)
# Use loc to retrieve the arousal value for the specified experiment code
  arousal_value = label_df.loc[label_df['experiment_code'] == target_experiment_code, 'arousal' ].values

  if arousal_value < 4:
      return 0
  else:
      return 1 #arousal_value

# %%
root_path
# Out:
# 'C:\\Users\\jogip\\Desktop\\NIT\\Data'

# %%
eeg_folder_path = root_path+'\Emotiv'+'\Emotiv'

import os

# Specify the root folder
# root_folder = '/path/to/your/root/folder'
fif_file_list =[]
# Walk through the root folder and its subfolders
for folder_path, subfolders, files in os.walk(eeg_folder_path):
    # print(f"Current folder: {folder_path}")
    fif_files = [os.path.join(folder_path, file) for file in files if file.endswith('.fif')]
    fif_file_list.extend(fif_files)
    # print(fif_files)
    # Print all files in the current subfolder
    # for file in fif_files:
    #     file_path = os.path.join(folder_path, file)
    #     print(f"  File: {file_path}")

# %%
def read_data(file_path):
    raw = mne.io.read_raw_fif(file_path, preload=True)

    #preprocess funtions
    raw.set_eeg_reference()
    raw.filter(l_freq=1,h_freq=45)
    return raw.get_data()

    # return epochs #trials,channel,length

# %%
len(fif_file_list)
# Out:
# 487

# %%
raw_list = []
labels_list = []

# Iterate through the EEG epoch files in the folder
for file_path in fif_file_list:
    # Load each epoch file using MNE
    label=get_label(file_path)
    labels_list.append(label)
    raw = read_data(file_path)
    raw_list.append(raw)
# Out:
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID07_eeg.fif...
#     Range : 0 ... 29480 =      0.000 ...   115.156 secs
# Ready.
# Reading 0 ... 29480  =      0.000 ...   115.156 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID09_eeg.fif...
#     Range : 0 ... 29853 =      0.000 ...   116.613 secs
# Ready.
# Reading 0 ... 29853  =      0.000 ...   116.613 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID11_eeg.fif...
#     Range : 0 ... 29714 =      0.000 ...   116.070 secs
# Ready.
# Reading 0 ... 29714  =      0.000 ...   116.070 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB03\SUB03VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID09_eeg.fif...
# ...
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID08_eeg.fif...
#     Range : 0 ... 27825 =      0.000 ...   108.691 secs
# Ready.
# Reading 0 ... 27825  =      0.000 ...   108.691 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)
#
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 1 - 45 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 1.00 Hz (-6 dB cutoff frequency: 0.50 Hz)
# - Upper passband edge: 45.00 Hz
# - Upper transition bandwidth: 11.25 Hz (-6 dB cutoff frequency: 50.62 Hz)
# - Filter length: 845 samples (3.301 s)

# %%
fif_file_list
# Out:
# ['C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB01\\SUB01VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB02\\SUB02VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB03\\SUB03VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB04\\SUB04VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB05\\SUB05VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB05\\SUB05VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB05\\SUB05VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB05\\SUB05VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB06\\SUB06VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB07\\SUB07VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB08\\SUB08VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB09\\SUB09VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB10\\SUB10VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB11\\SUB11VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB12\\SUB12VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB13\\SUB13VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB13\\SUB13VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB13\\SUB13VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB14\\SUB14VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB15\\SUB15VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB16\\SUB16VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB17\\SUB17VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB18\\SUB18VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB18\\SUB18VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB18\\SUB18VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB18\\SUB18VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB19\\SUB19VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB19\\SUB19VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB20\\SUB20VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB21\\SUB21VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB22\\SUB22VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB23\\SUB23VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB24\\SUB24VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB24\\SUB24VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB25\\SUB25VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB25\\SUB25VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB25\\SUB25VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB25\\SUB25VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB26\\SUB26VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB27\\SUB27VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB28\\SUB28VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB29\\SUB29VID25_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID01_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID02_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID03_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID04_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID05_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID07_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID08_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID09_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID10_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID11_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID12_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID13_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID14_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID15_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID16_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID17_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID18_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID19_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID20_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID21_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID23_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID24_eeg.fif',
#  'C:\\Users\\jogip\\Desktop\\NIT\\Data\\Emotiv\\Emotiv\\SUB30\\SUB30VID25_eeg.fif']

# %%
type(raw_list)
# Out:
# list

# %%
import numpy as np
from mne.io import read_raw_fif
from scipy.fft import fft

# Define a function to apply Fourier transform to each epoch
def apply_fourier_transform(data):
    # Assuming data has shape (channels, samples)
    transformed_data = np.abs(fft(data, axis=1))  # Calculate magnitude of the Fourier transform
    return transformed_data

raw_list_data = []
labels_list = []

# Iterate through the EEG epoch files in the folder
for file_path in fif_file_list:
    # Load each epoch file using MNE
    label = get_label(file_path)
    labels_list.append(label)
    
    # Read raw EEG data
    raw = read_raw_fif(file_path, preload=True)
    data, _ = raw[:, :]  # Get the EEG data as a NumPy array
    
    # Apply Fourier transform to the raw EEG data
    transformed_data = apply_fourier_transform(data)
    
    # Append the transformed data to the raw_list
    raw_list_data.append(transformed_data)
# Out:
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID07_eeg.fif...
#     Range : 0 ... 29480 =      0.000 ...   115.156 secs
# Ready.
# Reading 0 ... 29480  =      0.000 ...   115.156 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB01\SUB01VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID09_eeg.fif...
#     Range : 0 ... 29853 =      0.000 ...   116.613 secs
# Ready.
# Reading 0 ... 29853  =      0.000 ...   116.613 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID11_eeg.fif...
#     Range : 0 ... 29714 =      0.000 ...   116.070 secs
# Ready.
# Reading 0 ... 29714  =      0.000 ...   116.070 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB02\SUB02VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB03\SUB03VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB04\SUB04VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB05\SUB05VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB05\SUB05VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB05\SUB05VID08_eeg.fif...
#     Range : 0 ... 22943 =      0.000 ...    89.621 secs
# Ready.
# Reading 0 ... 22943  =      0.000 ...    89.621 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB05\SUB05VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB06\SUB06VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID01_eeg.fif...
#     Range : 0 ... 11821 =      0.000 ...    46.176 secs
# Ready.
# Reading 0 ... 11821  =      0.000 ...    46.176 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID08_eeg.fif...
#     Range : 0 ... 28446 =      0.000 ...   111.117 secs
# Ready.
# Reading 0 ... 28446  =      0.000 ...   111.117 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID18_eeg.fif...
#     Range : 0 ... 12649 =      0.000 ...    49.410 secs
# Ready.
# Reading 0 ... 12649  =      0.000 ...    49.410 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID19_eeg.fif...
#     Range : 0 ... 17082 =      0.000 ...    66.727 secs
# Ready.
# Reading 0 ... 17082  =      0.000 ...    66.727 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID20_eeg.fif...
#     Range : 0 ... 14034 =      0.000 ...    54.820 secs
# Ready.
# Reading 0 ... 14034  =      0.000 ...    54.820 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID23_eeg.fif...
#     Range : 0 ... 27949 =      0.000 ...   109.176 secs
# Ready.
# Reading 0 ... 27949  =      0.000 ...   109.176 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB07\SUB07VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID01_eeg.fif...
#     Range : 0 ... 15608 =      0.000 ...    60.969 secs
# Ready.
# Reading 0 ... 15608  =      0.000 ...    60.969 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID02_eeg.fif...
#     Range : 0 ... 30197 =      0.000 ...   117.957 secs
# Ready.
# Reading 0 ... 30197  =      0.000 ...   117.957 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID05_eeg.fif...
#     Range : 0 ... 46074 =      0.000 ...   179.977 secs
# Ready.
# Reading 0 ... 46074  =      0.000 ...   179.977 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID18_eeg.fif...
#     Range : 0 ... 11639 =      0.000 ...    45.465 secs
# Ready.
# Reading 0 ... 11639  =      0.000 ...    45.465 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB08\SUB08VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID07_eeg.fif...
#     Range : 0 ... 25307 =      0.000 ...    98.855 secs
# Ready.
# Reading 0 ... 25307  =      0.000 ...    98.855 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID11_eeg.fif...
#     Range : 0 ... 16625 =      0.000 ...    64.941 secs
# Ready.
# Reading 0 ... 16625  =      0.000 ...    64.941 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID14_eeg.fif...
#     Range : 0 ... 30067 =      0.000 ...   117.449 secs
# Ready.
# Reading 0 ... 30067  =      0.000 ...   117.449 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB09\SUB09VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB10\SUB10VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB11\SUB11VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID02_eeg.fif...
#     Range : 0 ... 30518 =      0.000 ...   119.211 secs
# Ready.
# Reading 0 ... 30518  =      0.000 ...   119.211 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID05_eeg.fif...
#     Range : 0 ... 43515 =      0.000 ...   169.980 secs
# Ready.
# Reading 0 ... 43515  =      0.000 ...   169.980 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID07_eeg.fif...
#     Range : 0 ... 24860 =      0.000 ...    97.109 secs
# Ready.
# Reading 0 ... 24860  =      0.000 ...    97.109 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID08_eeg.fif...
#     Range : 0 ... 27970 =      0.000 ...   109.258 secs
# Ready.
# Reading 0 ... 27970  =      0.000 ...   109.258 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID10_eeg.fif...
#     Range : 0 ... 28665 =      0.000 ...   111.973 secs
# Ready.
# Reading 0 ... 28665  =      0.000 ...   111.973 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID13_eeg.fif...
#     Range : 0 ... 28081 =      0.000 ...   109.691 secs
# Ready.
# Reading 0 ... 28081  =      0.000 ...   109.691 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID17_eeg.fif...
#     Range : 0 ... 26426 =      0.000 ...   103.227 secs
# Ready.
# Reading 0 ... 26426  =      0.000 ...   103.227 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID24_eeg.fif...
#     Range : 0 ... 30611 =      0.000 ...   119.574 secs
# Ready.
# Reading 0 ... 30611  =      0.000 ...   119.574 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB12\SUB12VID25_eeg.fif...
#     Range : 0 ... 27366 =      0.000 ...   106.898 secs
# Ready.
# Reading 0 ... 27366  =      0.000 ...   106.898 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB13\SUB13VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB13\SUB13VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB13\SUB13VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB14\SUB14VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB15\SUB15VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB15\SUB15VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB15\SUB15VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB15\SUB15VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# ...
# Ready.
# Reading 0 ... 30811  =      0.000 ...   120.355 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB27\SUB27VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID01_eeg.fif...
#     Range : 0 ... 15616 =      0.000 ...    61.000 secs
# Ready.
# Reading 0 ... 15616  =      0.000 ...    61.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID08_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB28\SUB28VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB29\SUB29VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID01_eeg.fif...
#     Range : 0 ... 6788 =      0.000 ...    26.516 secs
# Ready.
# Reading 0 ... 6788  =      0.000 ...    26.516 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID02_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID03_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID04_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID05_eeg.fif...
#     Range : 0 ... 46336 =      0.000 ...   181.000 secs
# Ready.
# Reading 0 ... 46336  =      0.000 ...   181.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID07_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID08_eeg.fif...
#     Range : 0 ... 27825 =      0.000 ...   108.691 secs
# Ready.
# Reading 0 ... 27825  =      0.000 ...   108.691 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID09_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID10_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID11_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID12_eeg.fif...
#     Range : 0 ... 38656 =      0.000 ...   151.000 secs
# Ready.
# Reading 0 ... 38656  =      0.000 ...   151.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID13_eeg.fif...
#     Range : 0 ... 31232 =      0.000 ...   122.000 secs
# Ready.
# Reading 0 ... 31232  =      0.000 ...   122.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID14_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID15_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID16_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID17_eeg.fif...
#     Range : 0 ... 30720 =      0.000 ...   120.000 secs
# Ready.
# Reading 0 ... 30720  =      0.000 ...   120.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID18_eeg.fif...
#     Range : 0 ... 16128 =      0.000 ...    63.000 secs
# Ready.
# Reading 0 ... 16128  =      0.000 ...    63.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID19_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID20_eeg.fif...
#     Range : 0 ... 16640 =      0.000 ...    65.000 secs
# Ready.
# Reading 0 ... 16640  =      0.000 ...    65.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID21_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID23_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID24_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...
# Opening raw data file C:\Users\jogip\Desktop\NIT\Data\Emotiv\Emotiv\SUB30\SUB30VID25_eeg.fif...
#     Range : 0 ... 30976 =      0.000 ...   121.000 secs
# Ready.
# Reading 0 ... 30976  =      0.000 ...   121.000 secs...

# %%
def make_windowing(X,Y):
    X_new = []
    Y_new = []
    npt = 128 # Window length
    stride = 128 # stride lenth
    ctr = 0
    for i in range(0,X.shape[0]):
        y = Y[i]
        a= X[i,:,:]
        a = a.transpose()
        a.shape
        val = 0
        kd=len(a)
        while val<=(len(a)-npt):
            x = a[val:val+npt,:]

            X_new.append(x.T)
            Y_new.append(y)
            val = val+stride

    return np.array(X_new),np.array(Y_new)

# %%
from scipy import stats
def mean(data):
    return np.mean(data,axis=-1)

def std(data):
    return np.std(data,axis=-1)

def ptp(data):
    return np.ptp(data,axis=-1)

def var(data):
      return np.var(data,axis=-1)

def minim(data):
      return np.min(data,axis=-1)


def maxim(data):
      return np.max(data,axis=-1)

def argminim(data):
      return np.argmin(data,axis=-1)


def argmaxim(data):
      return np.argmax(data,axis=-1)

def mean_square(data):
      return np.mean(data**2,axis=-1)

def rms(data): #root mean square
      return  np.sqrt(np.mean(data**2,axis=-1))

def abs_diffs_signal(data):
    return np.sum(np.abs(np.diff(data,axis=-1)),axis=-1)


def skewness(data):
    return stats.skew(data,axis=-1)

def kurtosis(data):
    return stats.kurtosis(data,axis=-1)

def concatenate_features(data):
    return np.concatenate((mean(data),
                           # std(data),
                          # ptp(data),
                          #  var(data),
                          #  minim(data),
                          #  maxim(data),
                          #  argminim(data),
                          #  argmaxim(data),
                            mean_square(data),
                            rms(data),
                         # abs_diffs_signal(data),
                           skewness(data),
                           kurtosis(data)
                          ), axis=-1)

# %%
from tqdm import tqdm
features=[]
for raw in tqdm(raw_list):
  features.append(concatenate_features(raw))
features=np.array(features)
labels = np.array(labels_list)
# Out:
# 100%|██████████| 487/487 [00:16<00:00, 30.16it/s]

# %% [markdown]
# # models

# %% [markdown]
# # Random classifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.1, random_state=42)

# Create a preprocessing pipeline with StandardScaler and PCA
pipeline = make_pipeline(StandardScaler(), PCA(n_components=35))

# Fit and transform the training data
X_train_preprocessed = pipeline.fit_transform(X_train)

# Transform the test data
X_test_preprocessed = pipeline.transform(X_test)

# Train a Random Forest classifier
clf = RandomForestClassifier(n_estimators=35, random_state=42)
clf.fit(X_train_preprocessed, y_train)

# Make predictions on the test set
y_pred = clf.predict(X_test_preprocessed)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)

precision = metrics.precision_score(y_test, y_pred, average='macro')
recall = metrics.recall_score(y_test, y_pred, average='macro')
f1 = metrics.f1_score(y_test, y_pred, average='macro')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
# Out:
# Accuracy: 0.7142857142857143
# Precision: 0.5952380952380952
# Recall: 0.5598290598290598
# F1-Score: 0.5602564102564103

# %%
from sklearn.model_selection import GridSearchCV

# Define the parameter grid for Grid Search
param_grid = {
    'n_estimators': [10, 20, 30, 40, 50],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Create the GridSearchCV object
grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5)

# Fit the grid search to the data
grid_search.fit(X_train_preprocessed, y_train)

# Print the best hyperparameters
print("Best Hyperparameters:", grid_search.best_params_)

# Make predictions on the test set using the best estimator
y_pred_grid = grid_search.best_estimator_.predict(X_test_preprocessed)

# Evaluate the classifier after hyperparameter tuning
accuracy_grid = accuracy_score(y_test, y_pred_grid)
precision_grid = metrics.precision_score(y_test, y_pred_grid, average='macro')
recall_grid = metrics.recall_score(y_test, y_pred_grid, average='macro')
f1_grid = metrics.f1_score(y_test, y_pred_grid, average='macro')

print("Accuracy after Hyperparameter Tuning:", accuracy_grid)
print("Precision after Hyperparameter Tuning:", precision_grid)
print("Recall after Hyperparameter Tuning:", recall_grid)
print("F1-Score after Hyperparameter Tuning:", f1_grid)
# Out:
# Best Hyperparameters: {'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 40}
# Accuracy after Hyperparameter Tuning: 0.673469387755102
# Precision after Hyperparameter Tuning: 0.4636363636363636
# Recall after Hyperparameter Tuning: 0.48290598290598286
# F1-Score after Hyperparameter Tuning: 0.4555555555555555

# %% [markdown]
# # multiple models

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline

# Assuming 'features' is a 2D array of statistical features and 'labels' is the corresponding labels

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.1, random_state=42)

# Create a preprocessing pipeline with StandardScaler and PCA
pipeline = make_pipeline(StandardScaler(), PCA(n_components=10))

# Fit and transform the training data
X_train_preprocessed = pipeline.fit_transform(X_train)

# Transform the test data
X_test_preprocessed = pipeline.transform(X_test)

# Train a Random Forest classifier
rf_clf = RandomForestClassifier(n_estimators=100, random_state=42)
rf_clf.fit(X_train_preprocessed, y_train)

# Train a Support Vector Machine classifier
svm_clf = SVC(kernel='linear', C=1.0, random_state=42)
svm_clf.fit(X_train_preprocessed, y_train)

# Train a k-Nearest Neighbors classifier
knn_clf = KNeighborsClassifier(n_neighbors=5)
knn_clf.fit(X_train_preprocessed, y_train)

# Make predictions on the test set for each classifier
rf_pred = rf_clf.predict(X_test_preprocessed)
svm_pred = svm_clf.predict(X_test_preprocessed)
knn_pred = knn_clf.predict(X_test_preprocessed)

# Evaluate the classifiers
rf_accuracy = accuracy_score(y_test, rf_pred)
svm_accuracy = accuracy_score(y_test, svm_pred)
knn_accuracy = accuracy_score(y_test, knn_pred)

print("Random Forest Accuracy:", rf_accuracy)
print("SVM Accuracy:", svm_accuracy)
print("k-Nearest Neighbors Accuracy:", knn_accuracy)
# Out:
# Random Forest Accuracy: 0.6938775510204082
# SVM Accuracy: 0.7346938775510204
# k-Nearest Neighbors Accuracy: 0.6938775510204082

# %% [markdown]
# # svc hyper parameter

# %%
# Define the parameter grid for Grid Search
svm_param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf', 'poly'],
    'gamma': ['scale', 'auto']
}

# Create the GridSearchCV object
svm_grid_search = GridSearchCV(SVC(random_state=42), svm_param_grid, cv=5)

# Fit the grid search to the data
svm_grid_search.fit(X_train_preprocessed, y_train)

# Print the best hyperparameters
print("SVM Best Hyperparameters:", svm_grid_search.best_params_)

# Make predictions on the test set using the best estimator
svm_best_pred = svm_grid_search.best_estimator_.predict(X_test_preprocessed)

# Evaluate the classifier after hyperparameter tuning
svm_best_accuracy = accuracy_score(y_test, svm_best_pred)
print("SVM Accuracy after Hyperparameter Tuning:", svm_best_accuracy)
# Out:
# SVM Best Hyperparameters: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# SVM Accuracy after Hyperparameter Tuning: 0.7346938775510204

# %% [markdown]
# # knn hyper parameter

# %%
# Define the parameter grid for Grid Search
knn_param_grid = {
    'n_neighbors': [3, 5, 7, 9],
    'weights': ['uniform', 'distance'],
    'p': [1, 2]
}

# Create the GridSearchCV object
knn_grid_search = GridSearchCV(KNeighborsClassifier(), knn_param_grid, cv=5)

# Fit the grid search to the data
knn_grid_search.fit(X_train_preprocessed, y_train)

# Print the best hyperparameters
print("k-Nearest Neighbors Best Hyperparameters:", knn_grid_search.best_params_)

# Make predictions on the test set using the best estimator
knn_best_pred = knn_grid_search.best_estimator_.predict(X_test_preprocessed)

# Evaluate the classifier after hyperparameter tuning
knn_best_accuracy = accuracy_score(y_test, knn_best_pred)
print("k-Nearest Neighbors Accuracy after Hyperparameter Tuning:", knn_best_accuracy)
# Out:
# k-Nearest Neighbors Best Hyperparameters: {'n_neighbors': 7, 'p': 2, 'weights': 'distance'}
# k-Nearest Neighbors Accuracy after Hyperparameter Tuning: 0.6530612244897959

# %% [markdown]
# # svc

# %%
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline

# Assuming 'features' is your input data and 'labels' is the target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Create a preprocessing pipeline with StandardScaler and PCA
pipeline = make_pipeline(StandardScaler(), PCA(n_components=35))

# Fit and transform the training data
X_train_preprocessed = pipeline.fit_transform(X_train)

# Transform the test data
X_test_preprocessed = pipeline.transform(X_test)

# Train a Support Vector Classifier
svc = SVC(kernel='linear', C=1.0, random_state=42)
svc.fit(X_train_preprocessed, y_train)

# Make predictions on the test set
y_pred = svc.predict(X_test_preprocessed)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='macro')
recall = recall_score(y_test, y_pred, average='macro')
f1 = f1_score(y_test, y_pred, average='macro')

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1-Score:", f1)
# Out:
# Accuracy: 0.7857142857142857
# Precision: 0.890625
# Recall: 0.5434782608695652
# F1-Score: 0.5185964912280702

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# Assuming 'features' is your input data and 'labels' is the target variable

# Create a preprocessing pipeline with StandardScaler and PCA
pipeline = make_pipeline(StandardScaler(), PCA(n_components=35))

# Fit and transform the training data
X_train_preprocessed = pipeline.fit_transform(X_train)

# Define the parameter grid for GridSearchCV
param_grid = {'svc__C': [0.1, 1, 10], 'svc__kernel': ['linear', 'rbf'], 'svc__gamma': ['scale', 'auto']}

# Create an SVC model
svc = SVC(random_state=42)

# Create a pipeline with the preprocessing and the SVC model
full_pipeline = make_pipeline(pipeline, svc)

# Use GridSearchCV to find the best hyperparameters
grid_search = GridSearchCV(full_pipeline, param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Print the best hyperparameters
print("Best Parameters:", grid_search.best_params_)

# Make predictions on the test set using the best estimator
y_pred = grid_search.best_estimator_.predict(X_test)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Best Parameters: {'svc__C': 0.1, 'svc__gamma': 'scale', 'svc__kernel': 'rbf'}
# Accuracy: 0.7653061224489796

# %% [markdown]
# # deep learning

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_classification
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Assuming 'features' is your input data and 'labels' is the target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.1, random_state=42)

# Create a preprocessing pipeline with StandardScaler and PCA
pipeline = make_pipeline(StandardScaler(), PCA(n_components=35))

# Fit and transform the training data
X_train_preprocessed = pipeline.fit_transform(X_train)

# Transform the test data
X_test_preprocessed = pipeline.transform(X_test)

# Create a simple neural network model with Keras
def create_neural_network(input_dim):
    model = Sequential()
    model.add(Dense(64, input_dim=input_dim, activation='relu'))
    model.add(Dense(32, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

# Get the number of features after PCA
input_dim = X_train_preprocessed.shape[1]

# Create the neural network model
model = create_neural_network(input_dim)

# Train the model
model.fit(X_train_preprocessed, y_train, epochs=5, batch_size=32, validation_split=0.1)

# Make predictions on the test set
y_pred_probs = model.predict(X_test_preprocessed)
y_pred = np.round(y_pred_probs)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/5
# 13/13 [==============================] - 1s 15ms/step - loss: 0.7167 - accuracy: 0.5203 - val_loss: 0.5981 - val_accuracy: 0.7500
# Epoch 2/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6390 - accuracy: 0.6929 - val_loss: 0.5841 - val_accuracy: 0.7500
# Epoch 3/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.6167 - accuracy: 0.6954 - val_loss: 0.5888 - val_accuracy: 0.7500
# Epoch 4/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5955 - accuracy: 0.7005 - val_loss: 0.5904 - val_accuracy: 0.7727
# Epoch 5/5
# 13/13 [==============================] - 0s 5ms/step - loss: 0.5784 - accuracy: 0.7107 - val_loss: 0.5941 - val_accuracy: 0.7500
# 2/2 [==============================] - 0s 5ms/step
# Accuracy: 0.7755102040816326

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# Assuming 'features' is your input data and 'labels' is the target variable

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.1, random_state=42)

# Create a preprocessing pipeline with StandardScaler and PCA
pipeline = make_pipeline(StandardScaler(), PCA(n_components=35))

# Fit and transform the training data
X_train_preprocessed = pipeline.fit_transform(X_train)

# Transform the test data
X_test_preprocessed = pipeline.transform(X_test)

# Reshape data for CNN (assuming it's in the shape suitable for images)
X_train_cnn = X_train_preprocessed.reshape(-1, 7, 5, 1)
X_test_cnn = X_test_preprocessed.reshape(-1, 7, 5, 1)

# Create a simple CNN model
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(7, 5, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the CNN model
model.fit(X_train_cnn, y_train, epochs=5, batch_size=32, validation_split=0.1)

# Make predictions on the test set
y_pred_probs = model.predict(X_test_cnn)
y_pred = np.round(y_pred_probs)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/5
# 13/13 [==============================] - 1s 18ms/step - loss: 0.6421 - accuracy: 0.6980 - val_loss: 0.6145 - val_accuracy: 0.7500
# Epoch 2/5
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6300 - accuracy: 0.7005 - val_loss: 0.6085 - val_accuracy: 0.7500
# Epoch 3/5
# 13/13 [==============================] - 0s 7ms/step - loss: 0.6148 - accuracy: 0.7005 - val_loss: 0.6001 - val_accuracy: 0.7500
# Epoch 4/5
# 13/13 [==============================] - 0s 6ms/step - loss: 0.6065 - accuracy: 0.7005 - val_loss: 0.5983 - val_accuracy: 0.7500
# Epoch 5/5
# 13/13 [==============================] - 0s 6ms/step - loss: 0.5959 - accuracy: 0.6980 - val_loss: 0.5890 - val_accuracy: 0.7500
# 2/2 [==============================] - 0s 6ms/step
# Accuracy: 0.7346938775510204

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.datasets import make_classification
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# Generate synthetic data
X, y = make_classification(n_samples=1000, n_features=50, n_classes=2, random_state=42)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# Create a preprocessing pipeline with StandardScaler and PCA
pipeline = make_pipeline(StandardScaler(), PCA(n_components=35))

# Fit and transform the training data
X_train_preprocessed = pipeline.fit_transform(X_train)

# Transform the test data
X_test_preprocessed = pipeline.transform(X_test)

# Get the number of features after PCA
input_dim = X_train_preprocessed.shape[1]

# Create the neural network model
model = create_neural_network(input_dim)

# Train the model
model.fit(X_train_preprocessed, y_train, epochs=10, batch_size=32, validation_split=0.1)

# Make predictions on the test set
y_pred_probs = model.predict(X_test_preprocessed)
y_pred = np.round(y_pred_probs)

# Evaluate the classifier
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy}')
# Out:
# Epoch 1/10
# 26/26 [==============================] - 1s 7ms/step - loss: 0.6982 - accuracy: 0.5877 - val_loss: 0.6552 - val_accuracy: 0.6222
# Epoch 2/10
# 26/26 [==============================] - 0s 3ms/step - loss: 0.5528 - accuracy: 0.7568 - val_loss: 0.5719 - val_accuracy: 0.6889
# Epoch 3/10
# 26/26 [==============================] - 0s 3ms/step - loss: 0.4595 - accuracy: 0.8333 - val_loss: 0.5028 - val_accuracy: 0.7222
# Epoch 4/10
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3905 - accuracy: 0.8642 - val_loss: 0.4676 - val_accuracy: 0.8000
# Epoch 5/10
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3437 - accuracy: 0.8741 - val_loss: 0.4512 - val_accuracy: 0.8111
# Epoch 6/10
# 26/26 [==============================] - 0s 3ms/step - loss: 0.3150 - accuracy: 0.8877 - val_loss: 0.4524 - val_accuracy: 0.8222
# Epoch 7/10
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2939 - accuracy: 0.8877 - val_loss: 0.4538 - val_accuracy: 0.8333
# Epoch 8/10
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2790 - accuracy: 0.8988 - val_loss: 0.4564 - val_accuracy: 0.8333
# Epoch 9/10
# 26/26 [==============================] - 0s 4ms/step - loss: 0.2649 - accuracy: 0.8988 - val_loss: 0.4586 - val_accuracy: 0.8222
# Epoch 10/10
# 26/26 [==============================] - 0s 3ms/step - loss: 0.2506 - accuracy: 0.9074 - val_loss: 0.4675 - val_accuracy: 0.8222
# 4/4 [==============================] - 0s 2ms/step
# Accuracy: 0.89

# %%
# Make predictions on the training set
y_train_pred_probs = model.predict(X_train_preprocessed)
y_train_pred = np.round(y_train_pred_probs)

# Evaluate the classifier on the training set
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f'Training Accuracy: {train_accuracy}')
# Out:
# 29/29 [==============================] - 0s 1ms/step
# Training Accuracy: 0.9022222222222223

# %%
# Make predictions on the training set
y_train_pred
# Out:
# 29/29 [==============================] - 0s 4ms/step

# %%
# Make predictions on the training set
y_train_pred_probs = model.predict(X_train_preprocessed)
y_train_pred = np.round(y_train_pred_probs)
train_accuracy = accuracy_score(y_train, y_train_pred)
print(f'Training Accuracy: {train_accuracy}')
# Out:
# 29/29 [==============================] - 0s 2ms/step
# Training Accuracy: 0.9022222222222223
